# %% [markdown]
# Pandas

# %%
'''
Pandas-Mainly used by data analyst                                   
data - raw facts
information - providing meaning to the data

Name Dept marks
Ashika Cse 95
Aravinth BBA 96

1.SQL-Table format
2.Excel file
3.Text file
4.CSV file

pandas - used for data manipulation(READ,UPDATE,CREATE,)
csv-Comma seperated value 
dataframe
series

'''
1.open notepad
2.types values seperated by commas
3.Ctrl+s to save file with name sample.csv
4.after save,open with excel

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 31.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 KB 23.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.2/348.2 KB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 24.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   WARNING: The scripts f2py and numpy-config are installed in '/home/smce-sw/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
import pandas as pd

# %%
'''in pandas:
 1.Series - one row/one column
 2.Data frame - table format
 '''

# %%
import pandas as pd
df=pd.DataFrame({
    "Name":["Jack","Alex","Sofia"],
    "Department":["CSE","CSE","CSE"],
    "CGPA":[9.2,8,7]
})
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3581/2711066730.py in <module>
# ----> 1 import pandas as pd
#       2 df=pd.DataFrame({
#       3     "Name":["Jack","Alex","Sofia"],
#       4     "Department":["CSE","CSE","CSE"],
#       5     "CGPA":[9.2,8,7]
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df=pd.DataFrame({
    "Name":["Jack","Alex","Sofia"],
    "Department":["CSE","CSE","CSE"],
    "CGPA":[9.2,8,7]
})
print(df)
# Out:
#     Name Department  CGPA
# 0   Jack        CSE   9.2
# 1   Alex        CSE   8.0
# 2  Sofia        CSE   7.0

# %%
import pandas as pd
df=pd.DataFrame({
    "Name":["Ashika","Aravinth","Amutha"],
    "Department":["CSE","BBA","CSE"],
    "CGPA":[9.2,8,7],
    "Email":["123@gmail.com","123@gmail.com","143@gmail.com"]
})
print(df)
# Out:
#        Name Department  CGPA          Email
# 0    Ashika        CSE   9.2  123@gmail.com
# 1  Aravinth        BBA   8.0  123@gmail.com
# 2    Amutha        CSE   7.0  143@gmail.com

# %%
df["Name"].ndim #One dimensional
# Out:
# 1

# %%
df[["Name"]].ndim #Two dimensional
# Out:
# 2

# %%
f=67
f
# Out:
# 67

# %%
df["CGPA"]>9
# Out:
# 0     True
# 1    False
# 2    False
# Name: CGPA, dtype: bool

# %%
df[df["CGPA"]>9]
# Out:
#      Name Department  CGPA          Email
# 0  Ashika        CSE   9.2  123@gmail.com

# %%
df[df["CGPA"]>=8]
# Out:
#        Name Department  CGPA          Email
# 0    Ashika        CSE   9.2  123@gmail.com
# 1  Aravinth        BBA   8.0  123@gmail.com

# %%
df[(df["CGPA"]>=6)&(df["Email"]=="143@gmail.com")]
# Out:
#      Name Department  CGPA          Email
# 2  Amutha        CSE   7.0  143@gmail.com

# %%
df[(df["CGPA"]>=8)&(df["Email"]=="123@gmail.com")]
# Out:
#        Name Department  CGPA          Email
# 0    Ashika        CSE   9.2  123@gmail.com
# 1  Aravinth        BBA   8.0  123@gmail.com

# %%
df[(df["CGPA"]<8)]
# Out:
#      Name Department  CGPA          Email
# 2  Amutha        CSE   7.0  143@gmail.com

# %%
df[df["CGPA"]>=7]
# Out:
#        Name Department  CGPA          Email
# 0    Ashika        CSE   9.2  123@gmail.com
# 1  Aravinth        BBA   8.0  123@gmail.com
# 2    Amutha        CSE   7.0  143@gmail.com

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %%
df.shape
# Out:
# (3, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Department', 'CGPA', 'Email'], dtype='object')

# %%
a=int(input("Enter the number:"))
b=int(input("Enter the number:"))
c=a+b
c
# Out:
# Enter the number:45
# Enter the number:54
# 99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        3 non-null      object
#  1   Department  3 non-null      object
#  2   CGPA        3 non-null      float64
#  3   Email       3 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 224.0+ bytes

# %%
df.dtypes
# Out:
# Name           object
# Department     object
# CGPA          float64
# Email          object
# dtype: object

# %% [markdown]
# Missing values
#     -Not a Number(NaN)

# %%
df.isna().sum()
# isnull is also used to find whether the missing value is having or not
# Out:
# Name          0
# Department    0
# CGPA          0
# Email         0
# dtype: int64

# %%
import numpy as np
df2=pd.DataFrame({
    "order_id":["1003","1004","1005"],
    "location":["MAS",np.nan,"ED"],
    "amount":[2000,3000,8000]
})
df2
# Out:
#   order_id location  amount
# 0     1003      MAS    2000
# 1     1004      NaN    3000
# 2     1005       ED    8000

# %%
import numpy as np
df2=pd.DataFrame({
    "order_id":["1003","1004",np.nan],
    "location":["MAS",np.nan,"ED"],
    "amount":[2000,3000,8000]
})
df2
# Out:
#   order_id location  amount
# 0     1003      MAS    2000
# 1     1004      NaN    3000
# 2      NaN       ED    8000

# %%
import numpy as np
df2=pd.DataFrame({
    "order_id":["1003","1004",np.nan],
    "location":["MAS",np.nan,"ED"],
    "amount":[np.nan,3000,8000]
})
df2
# Out:
#   order_id location  amount
# 0     1003      MAS     NaN
# 1     1004      NaN  3000.0
# 2      NaN       ED  8000.0

# %%
df2["order_id"].fillna("10034",inplace=True)
# Out:
# /tmp/ipykernel_7924/2193855791.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["order_id"].fillna("10034",inplace=True)

# %%
df2["location"].fillna("cbe",inplace=True)
# Out:
# /tmp/ipykernel_7924/1071415416.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["location"].fillna("cbe",inplace=True)

# %%
'''
loc-label based indexing
Syntx:df.loc[row,col]
iloc-integer based indexing
'''

# %%
df2
# Out:
#   order_id location  amount
# 0     1003      MAS     NaN
# 1     1004      cbe  3000.0
# 2    10034       ED  8000.0

# %%
df2.loc[:,"order_id"] #all row+order_id columns
# Out:
# 0     1003
# 1     1004
# 2    10034
# Name: order_id, dtype: object

# %%
df2.loc[:1,:"location"]
# Out:
#   order_id location
# 0     1003      MAS
# 1     1004      cbe

# %%
df2.iloc[1:3,1]
# Out:
# 1    cbe
# 2     ED
# Name: location, dtype: object

# %%
df2.iloc[1:3,1:2]
# Out:
#   location
# 1      cbe
# 2       ED

# %%
df2.iloc[0,1]
# Out:
# 'MAS'

# %%
df2.iloc[0,1]="Chennai"

# %%
for i in range(5):
    for j in range(2):
        print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1
# 3 0
# 3 1
# 4 0
# 4 1

# %%
import pandas as pd
df=pd.read_csv("order.csv")
df.head()
df.head(2)
df.tail()
df.tail()
df.tail(2)
df.sample()
df.sample(2)
# Out:
#      order_id user_id restaurant_id  order_date  total_amount  \
# 1148  ORD1221  USR188        RST001  09/11/2024          1957
# 405   ORD0126  USR130        RST045  26/04/2024             0
#
#                                           items_ordered    payment_method  \
# 1148  Butter Naan, Masala Dosa, Paneer Butter Masala...            Wallet
# 405                Masala Dosa, Pav Bhaji, Idli Sambhar  Cash on Delivery
#
#      order_status      name_user  gender  city_user    name_restaurant  \
# 1148    Completed   Advik Bhatti    Male  Hyderabad     Spicy Bites #1
# 405     Cancelled  Oorja Shankar  Female    Kolkata  Spicy Kitchen #45
#
#      city_restaurant  avg_cost_for_two  rating  delivery_pertner_pay  \
# 1148       Hyderabad               490     4.3                136.99
# 405          Kolkata               372     3.4                160.79
#
#       delivery_time_min
# 1148               60.0
# 405                60.0

# %%
import pandas as pd
df=pd.read_csv("order.csv")
df
# Out:
#      order_id user_id restaurant_id  order_date  total_amount  \
# 0     ORD0001  USR002        RST007  01/04/2024          2188
# 1     ORD1933  USR080        RST007  26/03/2025           846
# 2     ORD1946  USR038        RST007  28/03/2025          1431
# 3     ORD1265  USR102        RST007  21/11/2024          1231
# 4     ORD1694  USR124        RST007  09/02/2025           523
# ...       ...     ...           ...         ...           ...
# 1963  ORD1068  USR125        RST073  12/10/2024          2359
# 1964  ORD0429  USR194        RST073  17/06/2024             0
# 1965  ORD1438  USR194        RST073  23/12/2024          1879
# 1966  ORD1325  USR090        RST073  01/12/2024          1397
# 1967  ORD1968  USR145        RST046  2025-05-28           560
#
#                                           items_ordered    payment_method  \
# 0                Fried Rice, Masala Dosa, Hakka Noodles       Credit Card
# ...
