# %% [markdown]
# ###Variables:

# %%
x=10
print(x)
# Out:
# 10

# %%
a=100
a
# Out:
# 100

# %%
a=10
b=55
c=a=b
c
# Out:
# 55

# %%
a=10
b=15
c=a+b
c
# Out:
# 25

# %%
x="Hello"
x
# Out:
# 'Hello'

# %%
n=0o101   #Octal value
x=0b101   #Binary value
y=0x12    #Hexadecimal value
z=3+5j    #complex number
k=4       #int
t=3.14    #float
type(k)
# Out:
# int

# %%
age=18
if age>=18:
    print("ELigible")
else:
    print("Not eligible")
print(age)
# Out:
# ELigible
# 18

# %%
True+1
# Out:
# 2

# %%
False+1
# Out:
# 1

# %%
True-1
# Out:
# 0

# %%
a=10
b=20
print(a>b)

# %%
s=24
print(s)

# %%
ch = input("Enter a character: ")

if ch.lower() == 'a' or ch.lower() == 'e' or ch.lower() == 'i' or ch.lower() == 'o' or ch.lower() == 'u':
    print(ch, "is a vowel")
else:
    print(ch, "is not a vowel")
