# %%
name_list = list()
for i in range(6):
    name_list.append(input("Enter the elements:"))
print(name_list)
# Out:
# Enter the elements:Ashika
# Enter the elements:Akshaya
# Enter the elements:Mahishma
# Enter the elements:Algin
# Enter the elements:Rakshini
# Enter the elements:Amutha
# ['Ashika', 'Akshaya', 'Mahishma', 'Algin', 'Rakshini', 'Amutha']

# %%
lst=[10,20,30,40,50,60]
del lst[1:3]
print(lst)
# Out:
# [10, 40, 50, 60]

# %%
lst=[10,20,30,40,50,60,70,80,90]

lst.remove(50)
print(lst)
# Out:
# [10, 20, 30, 40, 60, 70, 80, 90]

# %%
lst = [10,20,30,40,50]
lst.clear()
print(lst)
# Out:
# []

# %%
lst = [10, 20, 30, 40]

lst.clear()

print(lst)
# Out:
# []

# %%
lst = [10, 20, 30]

element = input("Enter an element: ")
lst.append(element)

print("Updated List:", lst)
# Out:
# Enter an element: 45
# Updated List: [10, 20, 30, '45']

# %%
lst = [10, 20, 30]

lst.extend([40, 50])

print(lst)
# Out:
# [10, 20, 30, 40, 50]

# %%
lst = [10, 20, 30, 20, 40, 10]

new_lst = list(set(lst))

print(new_lst)
# Out:
# [40, 10, 20, 30]

# %%
names = ["Ashika", "Amutha", "Aravinth", "Nadarajan"]

print("Ashika" in names)
# Out:
# True

# %%
fruits=["Apple","Orange","Grapes","Pineapple"]
print("Pomegranate" in fruits)
# Out:
# False

# %%
lst=[20,30,40,30,50]
lst_2=[]
for i in lst:
    if i not in lst_2:
        lst_2.append(i)
    print(lst_2)
# Out:
# [20]
# [20, 30]
# [20, 30, 40]
# [20, 30, 40]
# [20, 30, 40, 50]

# %%
lst = [10, 20, 30, 40, 50]

count = len(lst)

print(count)
# Out:
# 5

# %%
lst = [2, 0, 3, 4, 0, 0, 8, 0]

result = []

for i in lst:
    if i != 0:
        result.append(i)

for i in lst:
    if i == 0:
        result.append(i)

print(result)
# Out:
# [2, 3, 4, 8, 0, 0, 0, 0]

# %%
t=(1,)
type(t)
# Out:
# tuple

# %%
t=(1,2,3,4)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t=(5)
dir(t)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
lst=[1,2,3,]
t=tuple(lst)
print(lst)
# Out:
# [1, 2, 3]

# %% [markdown]
# ###Container 3:Set

# %%
s={10,20,30,40,50,40,20}
print(s)
type(s)
# Out:
# {50, 20, 40, 10, 30}
# set

# %%
s={}
print(type(s))
# Out:
# <class 'dict'>

# %%
s={10}
s.add(20)
s.add(30)
print(s)
# Out:
# {10, 20, 30}

# %%
lst_1=[12,34,56,67,78]
lst_2=[23,54,65,67,43]
list=lst_1+lst_2
print(list)
# Out:
# [12, 34, 56, 67, 78, 23, 54, 65, 67, 43]

# %%
lst_1=[12,34,56,67]
lst_2=[23,54,65]
print(list)
# Out:
# [12, 34, 56, 67, 78, 23, 54, 65, 67, 43]

# %%
lst_1=[45,67,45]
s=list_1.remove()
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_25856/728363574.py in <module>
#       1 lst_1=[45,67,45]
# ----> 2 s=list_1.remove()
#       3 print(s)
#
# NameError: name 'list_1' is not defined

# %%
student = {
    "name":"Ashika",
    "age":18,
    "Department":"CSE",
    "CGPA": 8.591,
}

print(student)
# Out:
# {'name': 'Ashika', 'age': 18, 'Department': 'CSE', 'CGPA': 8.591}

# %%
student = {
    "name": "Arun",
    "age": 21,
    "cgpa": 8.5,
    "department": "Computer Science"
}

print(student)
# Out:
# {'name': 'Arun', 'age': 21, 'cgpa': 8.5, 'department': 'Computer Science'}

# %%
name="Ashika"
print(name[0:4])
# Out:
# Ashi

# %%
print(name.upper())
# Out:
# ASHIKA

# %%
print(name.lower())
# Out:
# ashika

# %%
text = "I like Java"
print(text.replace("Java", "Python"))
# Out:
# I like Python

# %%
s="Hello"
d={}
for i in s:
    if i in d:
        d[i]+=1
    else:
        d[i]=1
print(d)
# Out:
# {'H': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
s="Hi there, how are you"
print(s.split())
# Out:
# ['Hi', 'there,', 'how', 'are', 'you']

# %%
s="H e l l o"
print(s[::-1])
# Out:
# o l l e H

# %%
n=5
all(n%i for i in range(2,n))
# Out:
# True

# %%
n=8
print("Prime" if all(n%i for i in range(2,n)else"Not Prime")
# Out:
#   File "/tmp/ipykernel_25856/505553522.py", line 2
#     print("Prime" if all(n%i for i in range(2,n)else"Not Prime")
#           ^
# SyntaxError: expected 'else' after 'if' expression

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

top = 0
bottom = len(matrix) - 1
left = 0
right = len(matrix[0]) - 1

while top <= bottom and left <= right:

    for i in range(left, right + 1):
        print(matrix[top][i], end=" ")
    top += 1

    for i in range(top, bottom + 1):
        print(matrix[i][right], end=" ")
    right -= 1

    if top <= bottom:
        for i in range(right, left - 1, -1):
            print(matrix[bottom][i], end=" ")
        bottom -= 1

    if left <= right:
        for i in range(bottom, top - 1, -1):
            print(matrix[i][left], end=" ")
        left += 1
# Out:
# 1 2 3 6 9 8 7 4 5
